# %%
# !unzip -q "/content/drive/MyDrive/deep/archive.zip" -d "/content/dataset/"

# %%
# !pip install thop
# Out:
# Requirement already satisfied: thop in /usr/local/lib/python3.12/dist-packages (0.1.1.post2209072238)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from thop) (2.11.0+cu128)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->thop) (3.29.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (4.15.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (2025.3.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->thop) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->thop) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->thop) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->thop) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->thop) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->thop) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->thop) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->thop) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->thop) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->thop) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->thop) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->thop) (12.8.90)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch->thop) (1.5.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->thop) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->thop) (3.0.3)

# %%
import numpy as np
import random
import torch
from sklearn.model_selection import train_test_split
np.random.seed(42)

# %%
INPUT_SIGNAL_TYPES = [
    "body_acc_x_",
    "body_acc_y_",
    "body_acc_z_",
    "body_gyro_x_",
    "body_gyro_y_",
    "body_gyro_z_",
    "total_acc_x_",
    "total_acc_y_",
    "total_acc_z_"
]

LABELS = [
    "WALKING",
    "WALKING_UPSTAIRS",
    "WALKING_DOWNSTAIRS",
    "SITTING",
    "STANDING",
    "LAYING"
]

# %%
TRAIN = "train/"
TEST = "test/"

DATASET_PATH = "/content/dataset/UCI-HAR Dataset/"

def load_X(X_signals_paths):
    X_signals = []

    for signal_type_path in X_signals_paths:
        series_list = []

        with open(signal_type_path, 'r') as file:
            for row in file:
                row_clean = row.replace('  ', ' ')
                row_clean = row_clean.strip()
                serie = row_clean.split(' ')
                serie_array = np.array(serie, dtype=np.float32)
                series_list.append(serie_array)

        X_signals.append(series_list)

    X_signals = np.array(X_signals)
    return np.transpose(X_signals, (1, 2, 0))

def load_y(y_path):
    with open(y_path, 'r') as file:
        labels = [int(line.strip()) for line in file]
    return np.array(labels, dtype=np.int32) - 1

# %%
X_train_signals_paths = [
    DATASET_PATH + TRAIN + "Inertial Signals/" + signal + "train.txt" for signal in INPUT_SIGNAL_TYPES
]
X_test_signals_paths = [
    DATASET_PATH + TEST + "Inertial Signals/" + signal + "test.txt" for signal in INPUT_SIGNAL_TYPES
]

y_train_path = DATASET_PATH + TRAIN + "y_train.txt"
y_test_path = DATASET_PATH + TEST + "y_test.txt"


X_train = load_X(X_train_signals_paths)
X_test = load_X(X_test_signals_paths)


y_train = load_y(y_train_path)
y_test = load_y(y_test_path)

print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
# Out:
# X_train shape: (7352, 128, 9)
# X_test shape: (2947, 128, 9)

# %%
# validation 데이터 생성
def load_subject(filepath):
    with open(filepath, "r") as f:
        return np.array([int(x.strip()) for x in f])

subject_train = load_subject(DATASET_PATH + TRAIN + "subject_train.txt")
print("subject_train shape:",  subject_train.shape)

subjects = np.unique(subject_train)
val_subjects = np.random.choice( subjects, size=4, replace=False )

print("val_subject: ", val_subjects)

val_mask = np.isin(subject_train, val_subjects)
train_mask = ~val_mask

X_val = X_train[val_mask]
y_val = y_train[val_mask]
X_train = X_train[train_mask]
y_train = y_train[train_mask]


subject_val = subject_train[val_mask]
subject_train = subject_train[train_mask]
print("Train subjects :", np.unique(subject_train))
print("Val subjects   :", np.unique(subject_val))
# Out:
# subject_train shape: (7352,)
# val_subject:  [26  8 17 14]
# Train subjects : [ 1  3  5  6  7 11 15 16 19 21 22 23 25 27 28 29 30]
# Val subjects   : [ 8 14 17 26]

# %%
# GPU 사용 가능 여부 확인 for pytorch
device_available = torch.cuda.is_available()
print(f"GPU 사용 가능 여부: {device_available}")

if device_available:
    device_name = torch.cuda.get_device_name(0)
    print(f"사용 중인 GPU 장치: {device_name}")

    device = torch.device("cuda")
    x = torch.tensor([1.0, 2.0]).to(device)
    print(f"텐서가 할당된 장치: {x.device}")
else:
    print("GPU를 인식하지 못했습니다. 설정을 다시 확인해주세요.")
    model = "cpu"
# Out:
# GPU 사용 가능 여부: True
# 사용 중인 GPU 장치: Tesla T4
# 텐서가 할당된 장치: cuda:0

# %%
import time
import pandas as pd
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from thop import profile
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.manifold import TSNE

# %%
class HAR_Dataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.float32).permute(0, 2, 1)  # (B, 9, 128)
        self.y = torch.tensor(y, dtype=torch.long)

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# %%
train_dataset = HAR_Dataset(X_train, y_train)
val_dataset = HAR_Dataset(X_val, y_val)
test_dataset  = HAR_Dataset(X_test, y_test)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader   = DataLoader(val_dataset, batch_size=64, shuffle=False)
test_loader  = DataLoader(test_dataset, batch_size=64, shuffle=False)

# %%
X_raw = X_test.reshape(X_test.shape[0], -1)

print(f"X_raw shape = {X_raw.shape}")

tsne = TSNE(
    n_components=2,
    perplexity=30,
    random_state=42
)

embedding = tsne.fit_transform(X_raw)

activity_names = [
    "Walking",
    "Walking Upstairs",
    "Walking Downstairs",
    "Sitting",
    "Standing",
    "Laying"
]

plt.figure(figsize=(10,8))

for i in range(6):
    idx = y_test == i

    plt.scatter(
        embedding[idx,0],
        embedding[idx,1],
        s=10,
        alpha=0.6,
        label=activity_names[i]
    )

plt.legend()
plt.title("Raw UCI-HAR t-SNE")
plt.show()
# Out:
# X_raw shape = (2947, 1152)

# %% [markdown]
# # **SENet의 SE Block을 구현해보자**
#
# Squeeze랑 Excitation만 하면 되지 뭐... \
# 더 정확히?
# 1. GAP로 Squeeze
# 2. FC 레이어(이 때 크기를 줄임)
# 3. ReLU
# 4. FC 레이어(이 때 크기를 복구)
# 5. sigmoid로 가중치 형태로 만들기
# 6. element-wise multiple로 가중치 부여
#
# Inception에 붙여보기

# %%
class SEBlock(nn.Module):
  def __init__(self, in_channels, r=4):
    super().__init__()

    reduced_channels = max(1, in_channels // r)
    self.squeeze = nn.AdaptiveAvgPool1d(1)

    self.excitation = nn.Sequential(
        nn.Conv1d(in_channels, reduced_channels, kernel_size=1, padding=0),
        nn.ReLU(),
        nn.Conv1d(reduced_channels, in_channels, kernel_size=1, padding=0),
        nn.Sigmoid()
    )


  def forward(self, x):
    squeezed = self.squeeze(x)
    weights = self.excitation(squeezed)

    return x * weights

# %%
class InceptionBlock(nn.Module):
  def __init__(self, in_channels, out_channels):
    super().__init__()

    mid_channels = out_channels // 4

    self.branch1 = nn.Sequential(
      nn.Conv1d(in_channels, mid_channels, kernel_size=1),
      nn.BatchNorm1d(mid_channels),
      nn.ReLU()
    )

    self.branch2 = nn.Sequential(
      nn.Conv1d(in_channels, mid_channels, kernel_size=3, padding=1),
      nn.BatchNorm1d(mid_channels),
      nn.ReLU()
    )

    self.branch3 = nn.Sequential(
      nn.Conv1d(in_channels, mid_channels, kernel_size=5, padding=2),
      nn.BatchNorm1d(mid_channels),
      nn.ReLU()
    )

    self.branch4 = nn.Sequential(
      nn.MaxPool1d(kernel_size=3, stride=1, padding=1),
      nn.Conv1d(in_channels, mid_channels, kernel_size=1),
      nn.BatchNorm1d(mid_channels),
      nn.ReLU()
    )

    total_mid_channels = mid_channels * 4

    self.proj = nn.Sequential(
      nn.Conv1d(total_mid_channels, out_channels, kernel_size=1),
      nn.BatchNorm1d(out_channels)
    )
    self.se = SEBlock(out_channels, r=4)



  def forward(self, x):
    f1 = self.branch1(x)
    f2 = self.branch2(x)
    f3 = self.branch3(x)
    f4 = self.branch4(x)

    out = torch.cat([f1, f2, f3, f4], dim=1)
    out = self.proj(out)
    out = self.se(out)
    return F.relu(out)

# %%
class MyModel(nn.Module):
    def __init__(self):
        super().__init__()

        self.prep = nn.Sequential(
            nn.Conv1d(9, 64, kernel_size=3, padding=1),
            nn.BatchNorm1d(64),
            nn.ReLU()
        )

        self.inception1 = InceptionBlock(64, 64)
        self.pool1 = nn.MaxPool1d(kernel_size=2)

        self.inception2 = InceptionBlock(64, 128)
        self.pool2 = nn.MaxPool1d(kernel_size=2)

        self.inception3 = InceptionBlock(128, 128)

        self.dropout = nn.Dropout(0.4)
        self.fc = nn.LazyLinear(6)

    def forward(self, x, return_feature=False):

        x = self.prep(x)

        x = self.inception1(x)
        x = self.pool1(x)
        x = self.inception2(x)
        x = self.pool2(x)
        x = self.inception3(x)

        x = F.adaptive_avg_pool1d(x, 1)
        feat = torch.flatten(x, 1)
        x = self.dropout(feat)
        logits = self.fc(x)

        if return_feature:
            return logits, feat

        return logits

# %%
def train(model, loader):
    model.train()

    total_loss = 0
    correct = 0
    total = 0

    for X, y in loader:
        X = X.to(device)
        y = y.to(device)
        optimizer.zero_grad()

        outputs = model(X)
        loss = criterion(outputs, y)

        loss.backward()
        optimizer.step()

        total_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total += y.size(0)
        correct += (predicted == y).sum().item()

    epoch_loss = total_loss / len(loader)
    epoch_acc = correct / total

    y_pred, y_true = evaluate(model, val_loader)
    val_acc = accuracy_score(y_true, y_pred)

    return epoch_loss, epoch_acc, val_acc

def evaluate(model, loader):
    model.eval()

    all_preds = []
    all_labels = []

    with torch.no_grad():
        for X, y in loader:
            X = X.to(device)
            y = y.to(device)
            outputs = model(X)
            preds = torch.argmax(outputs, dim=1)

            all_preds.append(preds)
            all_labels.append(y)

    return (torch.cat(all_preds).cpu(), torch.cat(all_labels).cpu())

def count_params(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def get_profile(model):
  dummy_input = torch.randn(1, 9, 128).to(device)
  flops, params = profile(model, inputs=(dummy_input,))
  return flops, params

def benchmark(model, loader):
  model.eval()
  torch.cuda.synchronize()

  start = time.time()
  with torch.no_grad():
    for x, _ in loader:
      x = x.to(device)
      _ = model(x)

  torch.cuda.synchronize()
  end = time.time()

  return end - start

def extract_features(model, loader):
    model.eval()

    features = []
    labels = []

    with torch.no_grad():
        for X, y in loader:
            X = X.to(device)

            _, feat = model(X, return_feature=True)

            features.append(feat.cpu().numpy())
            labels.append(y.numpy())

    features = np.concatenate(features)
    labels = np.concatenate(labels)

    return features, labels

# %%
model = MyModel().to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

for epoch in range(100):
    loss, acc, val_acc = train(model, train_loader)

    print(f"Epoch {epoch+1}: loss={loss:.4f} | accuracy={acc:.4f} | val_accuracy={val_acc:.4f}")
# Out:
# Epoch 1: loss=0.4642 | accuracy=0.8794 | val_accuracy=0.9047
# Epoch 2: loss=0.1537 | accuracy=0.9421 | val_accuracy=0.9010
# Epoch 3: loss=0.1395 | accuracy=0.9417 | val_accuracy=0.8248
# Epoch 4: loss=0.1186 | accuracy=0.9529 | val_accuracy=0.8666
# Epoch 5: loss=0.1233 | accuracy=0.9489 | val_accuracy=0.9304
# Epoch 6: loss=0.1153 | accuracy=0.9534 | val_accuracy=0.8974
# Epoch 7: loss=0.1135 | accuracy=0.9531 | val_accuracy=0.9003
# Epoch 8: loss=0.1150 | accuracy=0.9497 | val_accuracy=0.8783
# Epoch 9: loss=0.1146 | accuracy=0.9524 | val_accuracy=0.8710
# Epoch 10: loss=0.1113 | accuracy=0.9522 | val_accuracy=0.8915
# Epoch 11: loss=0.1072 | accuracy=0.9511 | val_accuracy=0.9157
# Epoch 12: loss=0.1036 | accuracy=0.9551 | val_accuracy=0.8930
# Epoch 13: loss=0.1120 | accuracy=0.9526 | val_accuracy=0.9260
# Epoch 14: loss=0.0989 | accuracy=0.9569 | val_accuracy=0.8988
# Epoch 15: loss=0.0936 | accuracy=0.9594 | val_accuracy=0.9135
# Epoch 16: loss=0.0892 | accuracy=0.9621 | val_accuracy=0.8908
# Epoch 17: loss=0.0901 | accuracy=0.9596 | val_accuracy=0.8871
# Epoch 18: loss=0.0935 | accuracy=0.9618 | val_accuracy=0.8768
# Epoch 19: loss=0.0903 | accuracy=0.9613 | val_accuracy=0.8937
# Epoch 20: loss=0.0849 | accuracy=0.9638 | val_accuracy=0.9194
# Epoch 21: loss=0.0791 | accuracy=0.9651 | val_accuracy=0.9164
# Epoch 22: loss=0.0893 | accuracy=0.9621 | val_accuracy=0.9113
# Epoch 23: loss=0.0745 | accuracy=0.9713 | val_accuracy=0.9113
# Epoch 24: loss=0.0796 | accuracy=0.9671 | val_accuracy=0.9216
# Epoch 25: loss=0.0761 | accuracy=0.9689 | val_accuracy=0.8996
# Epoch 26: loss=0.0721 | accuracy=0.9726 | val_accuracy=0.9267
# Epoch 27: loss=0.0697 | accuracy=0.9713 | val_accuracy=0.9186
# Epoch 28: loss=0.0711 | accuracy=0.9724 | val_accuracy=0.8959
# Epoch 29: loss=0.0647 | accuracy=0.9738 | val_accuracy=0.9098
# Epoch 30: loss=0.0593 | accuracy=0.9765 | val_accuracy=0.8702
# Epoch 31: loss=0.0600 | accuracy=0.9758 | val_accuracy=0.9216
# Epoch 32: loss=0.0654 | accuracy=0.9746 | val_accuracy=0.9245
# Epoch 33: loss=0.0526 | accuracy=0.9783 | val_accuracy=0.9120
# Epoch 34: loss=0.0562 | accuracy=0.9781 | val_accuracy=0.9384
# Epoch 35: loss=0.0473 | accuracy=0.9815 | val_accuracy=0.9113
# Epoch 36: loss=0.0461 | accuracy=0.9828 | val_accuracy=0.9164
# Epoch 37: loss=0.0448 | accuracy=0.9825 | val_accuracy=0.9032
# Epoch 38: loss=0.0425 | accuracy=0.9851 | val_accuracy=0.9069
# Epoch 39: loss=0.0450 | accuracy=0.9836 | val_accuracy=0.9157
# Epoch 40: loss=0.0495 | accuracy=0.9830 | val_accuracy=0.9069
# Epoch 41: loss=0.0404 | accuracy=0.9845 | val_accuracy=0.9106
# Epoch 42: loss=0.0522 | accuracy=0.9798 | val_accuracy=0.9355
# Epoch 43: loss=0.0467 | accuracy=0.9836 | val_accuracy=0.9179
# Epoch 44: loss=0.0328 | accuracy=0.9878 | val_accuracy=0.9245
# Epoch 45: loss=0.0347 | accuracy=0.9876 | val_accuracy=0.9113
# Epoch 46: loss=0.0340 | accuracy=0.9865 | val_accuracy=0.9318
# Epoch 47: loss=0.0246 | accuracy=0.9913 | val_accuracy=0.9194
# Epoch 48: loss=0.0286 | accuracy=0.9895 | val_accuracy=0.9230
# Epoch 49: loss=0.0366 | accuracy=0.9858 | val_accuracy=0.9260
# Epoch 50: loss=0.0393 | accuracy=0.9858 | val_accuracy=0.9106
# Epoch 51: loss=0.0328 | accuracy=0.9886 | val_accuracy=0.9164
# Epoch 52: loss=0.0308 | accuracy=0.9893 | val_accuracy=0.9172
# Epoch 53: loss=0.0291 | accuracy=0.9901 | val_accuracy=0.9208
# Epoch 54: loss=0.0274 | accuracy=0.9896 | val_accuracy=0.9238
# Epoch 55: loss=0.0319 | accuracy=0.9885 | val_accuracy=0.9194
# Epoch 56: loss=0.0336 | accuracy=0.9885 | val_accuracy=0.9274
# Epoch 57: loss=0.0287 | accuracy=0.9890 | val_accuracy=0.9348
# Epoch 58: loss=0.0225 | accuracy=0.9905 | val_accuracy=0.9157
# Epoch 59: loss=0.0226 | accuracy=0.9920 | val_accuracy=0.9230
# Epoch 60: loss=0.0332 | accuracy=0.9886 | val_accuracy=0.9230
# Epoch 61: loss=0.0264 | accuracy=0.9906 | val_accuracy=0.9289
# Epoch 62: loss=0.0195 | accuracy=0.9930 | val_accuracy=0.9150
# Epoch 63: loss=0.0252 | accuracy=0.9908 | val_accuracy=0.9062
# Epoch 64: loss=0.0221 | accuracy=0.9923 | val_accuracy=0.9516
# Epoch 65: loss=0.0306 | accuracy=0.9895 | val_accuracy=0.9223
# Epoch 66: loss=0.0264 | accuracy=0.9903 | val_accuracy=0.9062
# Epoch 67: loss=0.0232 | accuracy=0.9911 | val_accuracy=0.9098
# Epoch 68: loss=0.0210 | accuracy=0.9935 | val_accuracy=0.9084
# Epoch 69: loss=0.0170 | accuracy=0.9942 | val_accuracy=0.9216
# Epoch 70: loss=0.0221 | accuracy=0.9916 | val_accuracy=0.9172
# Epoch 71: loss=0.0137 | accuracy=0.9955 | val_accuracy=0.9128
# Epoch 72: loss=0.0154 | accuracy=0.9942 | val_accuracy=0.9194
# Epoch 73: loss=0.0145 | accuracy=0.9952 | val_accuracy=0.9304
# Epoch 74: loss=0.0169 | accuracy=0.9940 | val_accuracy=0.9238
# Epoch 75: loss=0.0201 | accuracy=0.9938 | val_accuracy=0.9296
# Epoch 76: loss=0.0133 | accuracy=0.9963 | val_accuracy=0.9267
# Epoch 77: loss=0.0171 | accuracy=0.9935 | val_accuracy=0.9238
# Epoch 78: loss=0.0177 | accuracy=0.9928 | val_accuracy=0.9238
# Epoch 79: loss=0.0156 | accuracy=0.9953 | val_accuracy=0.9311
# Epoch 80: loss=0.0156 | accuracy=0.9937 | val_accuracy=0.9282
# Epoch 81: loss=0.0118 | accuracy=0.9950 | val_accuracy=0.9282
# Epoch 82: loss=0.0199 | accuracy=0.9938 | val_accuracy=0.9032
# Epoch 83: loss=0.0191 | accuracy=0.9933 | val_accuracy=0.9098
# Epoch 84: loss=0.0157 | accuracy=0.9928 | val_accuracy=0.9260
# Epoch 85: loss=0.0102 | accuracy=0.9968 | val_accuracy=0.9274
# Epoch 86: loss=0.0073 | accuracy=0.9973 | val_accuracy=0.9333
# Epoch 87: loss=0.0148 | accuracy=0.9947 | val_accuracy=0.9296
# Epoch 88: loss=0.0164 | accuracy=0.9942 | val_accuracy=0.9282
# Epoch 89: loss=0.0127 | accuracy=0.9953 | val_accuracy=0.9245
# Epoch 90: loss=0.0212 | accuracy=0.9923 | val_accuracy=0.9413
# Epoch 91: loss=0.0127 | accuracy=0.9962 | val_accuracy=0.9333
# Epoch 92: loss=0.0099 | accuracy=0.9965 | val_accuracy=0.9311
# Epoch 93: loss=0.0128 | accuracy=0.9962 | val_accuracy=0.9238
# Epoch 94: loss=0.0204 | accuracy=0.9933 | val_accuracy=0.9230
# Epoch 95: loss=0.0091 | accuracy=0.9963 | val_accuracy=0.9348
# Epoch 96: loss=0.0117 | accuracy=0.9963 | val_accuracy=0.9267
# Epoch 97: loss=0.0128 | accuracy=0.9948 | val_accuracy=0.9311
# Epoch 98: loss=0.0113 | accuracy=0.9965 | val_accuracy=0.9340
# Epoch 99: loss=0.0102 | accuracy=0.9963 | val_accuracy=0.9326
# Epoch 100: loss=0.0106 | accuracy=0.9958 | val_accuracy=0.9377

# %%
y_pred, y_true = evaluate(model, test_loader)

acc = accuracy_score(y_true, y_pred)
prec = precision_score(y_true, y_pred, average="macro")
rec = recall_score(y_true, y_pred, average="macro")
f1 = f1_score(y_true, y_pred, average="macro")

print(f"accuracy = {acc}\nprecision = {prec}\nrecall = {rec}\nf1-score = {f1}")
# Out:
# accuracy = 0.9535120461486257
# precision = 0.9577358400816974
# recall = 0.953079391555109
# f1-score = 0.9532837186340011

# %%
model_profile = get_profile(model)
latency = benchmark(model, test_loader)

data = {
    "Model": ["CNN1D"],
    "Params (K)": int(model_profile[1]),
    "FLOPs (M)": model_profile[0],
    "Latency (ms)": latency,
}

df = pd.DataFrame(data)
df
# Out:
# [INFO] Register count_convNd() for <class 'torch.nn.modules.conv.Conv1d'>.
# [INFO] Register count_normalization() for <class 'torch.nn.modules.batchnorm.BatchNorm1d'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.activation.ReLU'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.container.Sequential'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.pooling.MaxPool1d'>.
# [INFO] Register count_adap_avgpool() for <class 'torch.nn.modules.pooling.AdaptiveAvgPool1d'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.dropout.Dropout'>.
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
#    Model  Params (K)  FLOPs (M)  Latency (ms)
# 0  CNN1D      131990  6487104.0      0.222078

# %%
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8,6))

sns.heatmap(cm,
            annot=True,
            fmt='d',
            cmap='Blues')

plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix (UCI-HAR)")
plt.show()

# %%
features, labels = extract_features(model, test_loader)

tsne = TSNE(
    n_components=2,
    perplexity=30,
    random_state=42
)

embedding = tsne.fit_transform(features)


activity_names = [
    "Walking",
    "Walking Upstairs",
    "Walking Downstairs",
    "Sitting",
    "Standing",
    "Laying"
]

plt.figure(figsize=(10,8))

for i in range(6):
    idx = labels == i

    plt.scatter(
        embedding[idx,0],
        embedding[idx,1],
        label=activity_names[i],
        alpha=0.6,
        s=10
    )

plt.legend()
plt.title("t-SNE of CNN Features")
plt.show()
