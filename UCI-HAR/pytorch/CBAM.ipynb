# %%
# !unzip -q "/content/drive/MyDrive/deep/archive.zip" -d "/content/dataset/"

# %%
# !pip install thop
# Out:
# Collecting thop
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from thop) (2.11.0+cu128)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->thop) (3.29.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (4.15.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (2025.3.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->thop) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->thop) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->thop) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->thop) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->thop) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->thop) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->thop) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->thop) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->thop) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->thop) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->thop) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->thop) (12.8.90)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch->thop) (1.5.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->thop) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->thop) (3.0.3)
# Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Installing collected packages: thop
# Successfully installed thop-0.1.1.post2209072238

# %%
import numpy as np
import random
import torch
np.random.seed(42)
random.seed(42)

# %%
INPUT_SIGNAL_TYPES = [
    "body_acc_x_",
    "body_acc_y_",
    "body_acc_z_",
    "body_gyro_x_",
    "body_gyro_y_",
    "body_gyro_z_",
    "total_acc_x_",
    "total_acc_y_",
    "total_acc_z_"
]

LABELS = [
    "WALKING",
    "WALKING_UPSTAIRS",
    "WALKING_DOWNSTAIRS",
    "SITTING",
    "STANDING",
    "LAYING"
]

# %%
TRAIN = "train/"
TEST = "test/"

DATASET_PATH = "/content/dataset/UCI-HAR Dataset/"

def load_X(X_signals_paths):
    X_signals = []

    for signal_type_path in X_signals_paths:
        series_list = []

        with open(signal_type_path, 'r') as file:
            for row in file:
                row_clean = row.replace('  ', ' ')
                row_clean = row_clean.strip()
                serie = row_clean.split(' ')
                serie_array = np.array(serie, dtype=np.float32)
                series_list.append(serie_array)

        X_signals.append(series_list)

    X_signals = np.array(X_signals)
    return np.transpose(X_signals, (1, 2, 0))

def load_y(y_path):
    with open(y_path, 'r') as file:
        labels = [int(line.strip()) for line in file]
    return np.array(labels, dtype=np.int32) - 1

# %%
X_train_signals_paths = [
    DATASET_PATH + TRAIN + "Inertial Signals/" + signal + "train.txt" for signal in INPUT_SIGNAL_TYPES
]
X_test_signals_paths = [
    DATASET_PATH + TEST + "Inertial Signals/" + signal + "test.txt" for signal in INPUT_SIGNAL_TYPES
]

y_train_path = DATASET_PATH + TRAIN + "y_train.txt"
y_test_path = DATASET_PATH + TEST + "y_test.txt"


X_train = load_X(X_train_signals_paths)
X_test = load_X(X_test_signals_paths)


y_train = load_y(y_train_path)
y_test = load_y(y_test_path)

print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
# Out:
# X_train shape: (7352, 128, 9)
# X_test shape: (2947, 128, 9)

# %%
# validation 데이터 생성
def load_subject(filepath):
    with open(filepath, "r") as f:
        return np.array([int(x.strip()) for x in f])

subject_train = load_subject(DATASET_PATH + TRAIN + "subject_train.txt")
print("subject_train shape:",  subject_train.shape)

subjects = np.unique(subject_train)
val_subjects = np.random.choice( subjects, size=4, replace=False )

print("val_subject: ", val_subjects)

val_mask = np.isin(subject_train, val_subjects)
train_mask = ~val_mask

X_val = X_train[val_mask]
y_val = y_train[val_mask]
X_train = X_train[train_mask]
y_train = y_train[train_mask]


subject_val = subject_train[val_mask]
subject_train = subject_train[train_mask]
print("Train subjects :", np.unique(subject_train))
print("Val subjects   :", np.unique(subject_val))
# Out:
# subject_train shape: (7352,)
# val_subject:  [ 1 27 25  3]
# Train subjects : [ 5  6  7  8 11 14 15 16 17 19 21 22 23 26 28 29 30]
# Val subjects   : [ 1  3 25 27]

# %%
# GPU 사용 가능 여부 확인 for pytorch
device_available = torch.cuda.is_available()
print(f"GPU 사용 가능 여부: {device_available}")

if device_available:
    device_name = torch.cuda.get_device_name(0)
    print(f"사용 중인 GPU 장치: {device_name}")

    device = torch.device("cuda")
    x = torch.tensor([1.0, 2.0]).to(device)
    print(f"텐서가 할당된 장치: {x.device}")
else:
    print("GPU를 인식하지 못했습니다. 설정을 다시 확인해주세요.")
    model = "cpu"
# Out:
# GPU 사용 가능 여부: True
# 사용 중인 GPU 장치: Tesla T4
# 텐서가 할당된 장치: cuda:0

# %%
import time
import pandas as pd
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from thop import profile
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.manifold import TSNE

# %%
class HAR_Dataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.float32).permute(0, 2, 1)  # (B, 9, 128)
        self.y = torch.tensor(y, dtype=torch.long)

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# %%
train_dataset = HAR_Dataset(X_train, y_train)
val_dataset = HAR_Dataset(X_val, y_val)
test_dataset  = HAR_Dataset(X_test, y_test)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader   = DataLoader(val_dataset, batch_size=64, shuffle=False)
test_loader  = DataLoader(test_dataset, batch_size=64, shuffle=False)

# %%
X_raw = X_test.reshape(X_test.shape[0], -1)

print(f"X_raw shape = {X_raw.shape}")

tsne = TSNE(
    n_components=2,
    perplexity=30,
    random_state=42
)

embedding = tsne.fit_transform(X_raw)

activity_names = [
    "Walking",
    "Walking Upstairs",
    "Walking Downstairs",
    "Sitting",
    "Standing",
    "Laying"
]

plt.figure(figsize=(10,8))

for i in range(6):
    idx = y_test == i

    plt.scatter(
        embedding[idx,0],
        embedding[idx,1],
        s=10,
        alpha=0.6,
        label=activity_names[i]
    )

plt.legend()
plt.title("Raw UCI-HAR t-SNE")
plt.show()
# Out:
# X_raw shape = (2947, 1152)

# %% [markdown]
# # **CBAM을 구현해보자**
#
#
#
# CBAM 블록:
# Channel attention -> Spatial attention 이므로 \
# (max Pool, avg Pool) -> MLP -> (채널방향 max Pool, avg Pool) \
# 으로 구현하면 될듯

# %%
class ChannelAttention1D(nn.Module):
  def __init__(self, in_channels, r=4):
    super().__init__()

    self.avg_pool = nn.AdaptiveAvgPool1d(1)
    self.max_pool = nn.AdaptiveMaxPool1d(1)

    self.mlp = nn.Sequential(
        nn.Conv1d(in_channels, in_channels // r, kernel_size=1, bias=False), # MLP 구현을 위해 1x1 Conv 사용
        nn.ReLU(),
        nn.Conv1d(in_channels // r, in_channels, kernel_size=1, bias=False)
    )
    self.sigmoid = nn.Sigmoid()
  def forward(self, x):
    avg_raw = self.avg_pool(x)
    max_raw = self.max_pool(x)

    avg_mlp = self.mlp(avg_raw)
    max_mlp = self.mlp(max_raw)
    w = self.sigmoid(avg_mlp + max_mlp)
    return w * x


class SpatialAttention1D(nn.Module):
  def __init__(self, kernel_size=7):
    super().__init__()

    self.conv = nn.Conv1d(2, 1, kernel_size=kernel_size, padding='same')
    self.sigmoid = nn.Sigmoid()

  def forward(self, x):
    max_out = torch.max(x, dim=1, keepdim=True)[0]
    avg_out = torch.mean(x, dim=1, keepdim=True)

    spatial_feat = torch.cat([max_out, avg_out], dim=1)

    w = self.sigmoid(self.conv(spatial_feat))
    return w * x

# %%
class CBAM1D(nn.Module):
  def __init__(self, in_channels, kernel_size=7, r=4):
    super().__init__()

    self.ca = ChannelAttention1D(in_channels, r)
    self.sa = SpatialAttention1D(kernel_size)

  def forward(self, x):
    x = self.ca(x)
    x = self.sa(x)

    return x

# %%
class MyModel(nn.Module):
    def __init__(self, ):
        super().__init__()

        self.block1 = nn.Sequential(
            nn.Conv1d(9, 64, kernel_size=5, padding=2),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            CBAM1D(in_channels=64),
            nn.MaxPool1d(2)
        )

        self.block2 = nn.Sequential(
            nn.Conv1d(64, 128, kernel_size=5, padding=2),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            CBAM1D(in_channels=128),
        )

        self.avg_pool = nn.AdaptiveAvgPool1d(1)
        self.dropout = nn.Dropout(0.4)
        self.fc = nn.LazyLinear(6)



    def forward(self, x, return_feature=False):
        x = self.block1(x)
        x = self.block2(x)

        x = self.avg_pool(x)
        feat = torch.flatten(x, 1)
        x = self.dropout(feat)
        logits = self.fc(x)
        if return_feature:
            return logits, feat

        return logits

# %%
def train(model, loader):
    model.train()

    total_loss = 0
    correct = 0
    total = 0

    for X, y in loader:
        X = X.to(device)
        y = y.to(device)
        optimizer.zero_grad()

        outputs = model(X)
        loss = criterion(outputs, y)

        loss.backward()
        optimizer.step()

        total_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total += y.size(0)
        correct += (predicted == y).sum().item()

    epoch_loss = total_loss / len(loader)
    epoch_acc = correct / total

    y_pred, y_true = evaluate(model, val_loader)
    val_acc = accuracy_score(y_true, y_pred)

    return epoch_loss, epoch_acc, val_acc

def evaluate(model, loader):
    model.eval()

    all_preds = []
    all_labels = []

    with torch.no_grad():
        for X, y in loader:
            X = X.to(device)
            y = y.to(device)
            outputs = model(X)
            preds = torch.argmax(outputs, dim=1)

            all_preds.append(preds)
            all_labels.append(y)

    return (torch.cat(all_preds).cpu(), torch.cat(all_labels).cpu())

def count_params(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def get_profile(model):
  dummy_input = torch.randn(1, 9, 128).to(device)
  flops, params = profile(model, inputs=(dummy_input,))
  return flops, params

def benchmark(model, loader):
  model.eval()
  torch.cuda.synchronize()

  start = time.time()
  with torch.no_grad():
    for x, _ in loader:
      x = x.to(device)
      _ = model(x)

  torch.cuda.synchronize()
  end = time.time()

  return end - start

def extract_features(model, loader):
    model.eval()

    features = []
    labels = []

    with torch.no_grad():
        for X, y in loader:
            X = X.to(device)

            _, feat = model(X, return_feature=True)

            features.append(feat.cpu().numpy())
            labels.append(y.numpy())

    features = np.concatenate(features)
    labels = np.concatenate(labels)

    return features, labels

# %%
model = MyModel().to(device)

criterion = nn.CrossEntropyLoss(label_smoothing=0.1)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

for epoch in range(100):
    loss, acc, val_acc = train(model, train_loader)

    print(f"Epoch {epoch+1}: loss={loss:.4f} | accuracy={acc:.4f} | val_accuracy={val_acc:.4f}")
# Out:
# Epoch 1: loss=0.8940 | accuracy=0.8262 | val_accuracy=0.9932
# Epoch 2: loss=0.5802 | accuracy=0.9371 | val_accuracy=0.9701
# Epoch 3: loss=0.5616 | accuracy=0.9413 | val_accuracy=0.9742
# Epoch 4: loss=0.5529 | accuracy=0.9445 | val_accuracy=0.9735
# Epoch 5: loss=0.5500 | accuracy=0.9427 | val_accuracy=0.9681
# Epoch 6: loss=0.5427 | accuracy=0.9474 | val_accuracy=0.9742
# Epoch 7: loss=0.5403 | accuracy=0.9480 | val_accuracy=0.9728
# Epoch 8: loss=0.5415 | accuracy=0.9444 | val_accuracy=0.9640
# Epoch 9: loss=0.5374 | accuracy=0.9464 | val_accuracy=0.9722
# Epoch 10: loss=0.5387 | accuracy=0.9478 | val_accuracy=0.9708
# Epoch 11: loss=0.5326 | accuracy=0.9497 | val_accuracy=0.9742
# Epoch 12: loss=0.5273 | accuracy=0.9537 | val_accuracy=0.9742
# Epoch 13: loss=0.5253 | accuracy=0.9519 | val_accuracy=0.9708
# Epoch 14: loss=0.5229 | accuracy=0.9520 | val_accuracy=0.9627
# Epoch 15: loss=0.5197 | accuracy=0.9580 | val_accuracy=0.9742
# Epoch 16: loss=0.5230 | accuracy=0.9568 | val_accuracy=0.9654
# Epoch 17: loss=0.5199 | accuracy=0.9554 | val_accuracy=0.9688
# Epoch 18: loss=0.5143 | accuracy=0.9583 | val_accuracy=0.9728
# Epoch 19: loss=0.5159 | accuracy=0.9587 | val_accuracy=0.9695
# Epoch 20: loss=0.5119 | accuracy=0.9612 | val_accuracy=0.9728
# Epoch 21: loss=0.5078 | accuracy=0.9622 | val_accuracy=0.9633
# Epoch 22: loss=0.5049 | accuracy=0.9643 | val_accuracy=0.9688
# Epoch 23: loss=0.4985 | accuracy=0.9706 | val_accuracy=0.9708
# Epoch 24: loss=0.4976 | accuracy=0.9662 | val_accuracy=0.9260
# Epoch 25: loss=0.4964 | accuracy=0.9685 | val_accuracy=0.9688
# Epoch 26: loss=0.5013 | accuracy=0.9656 | val_accuracy=0.9572
# Epoch 27: loss=0.4945 | accuracy=0.9711 | val_accuracy=0.9708
# Epoch 28: loss=0.4891 | accuracy=0.9758 | val_accuracy=0.9525
# Epoch 29: loss=0.4835 | accuracy=0.9772 | val_accuracy=0.9715
# Epoch 30: loss=0.4791 | accuracy=0.9782 | val_accuracy=0.9674
# Epoch 31: loss=0.4881 | accuracy=0.9760 | val_accuracy=0.9620
# Epoch 32: loss=0.4868 | accuracy=0.9770 | val_accuracy=0.9688
# Epoch 33: loss=0.4858 | accuracy=0.9748 | val_accuracy=0.9593
# Epoch 34: loss=0.4781 | accuracy=0.9813 | val_accuracy=0.9423
# Epoch 35: loss=0.4775 | accuracy=0.9811 | val_accuracy=0.9688
# Epoch 36: loss=0.4793 | accuracy=0.9784 | val_accuracy=0.9470
# Epoch 37: loss=0.4710 | accuracy=0.9845 | val_accuracy=0.9681
# Epoch 38: loss=0.4707 | accuracy=0.9855 | val_accuracy=0.9633
# Epoch 39: loss=0.4744 | accuracy=0.9828 | val_accuracy=0.9776
# Epoch 40: loss=0.4689 | accuracy=0.9864 | val_accuracy=0.9654
# Epoch 41: loss=0.4659 | accuracy=0.9855 | val_accuracy=0.9708
# Epoch 42: loss=0.4650 | accuracy=0.9871 | val_accuracy=0.9294
# Epoch 43: loss=0.4639 | accuracy=0.9876 | val_accuracy=0.9566
# Epoch 44: loss=0.4649 | accuracy=0.9867 | val_accuracy=0.9328
# Epoch 45: loss=0.4626 | accuracy=0.9879 | val_accuracy=0.9599
# Epoch 46: loss=0.4685 | accuracy=0.9852 | val_accuracy=0.9423
# Epoch 47: loss=0.4639 | accuracy=0.9895 | val_accuracy=0.9566
# Epoch 48: loss=0.4646 | accuracy=0.9869 | val_accuracy=0.9437
# Epoch 49: loss=0.4603 | accuracy=0.9901 | val_accuracy=0.9661
# Epoch 50: loss=0.4661 | accuracy=0.9854 | val_accuracy=0.9695
# Epoch 51: loss=0.4600 | accuracy=0.9893 | val_accuracy=0.9817
# Epoch 52: loss=0.4618 | accuracy=0.9893 | val_accuracy=0.9627
# Epoch 53: loss=0.4576 | accuracy=0.9906 | val_accuracy=0.9722
# Epoch 54: loss=0.4627 | accuracy=0.9883 | val_accuracy=0.9722
# Epoch 55: loss=0.4596 | accuracy=0.9888 | val_accuracy=0.9742
# Epoch 56: loss=0.4550 | accuracy=0.9918 | val_accuracy=0.9701
# Epoch 57: loss=0.4634 | accuracy=0.9886 | val_accuracy=0.9233
# Epoch 58: loss=0.4567 | accuracy=0.9898 | val_accuracy=0.9423
# Epoch 59: loss=0.4605 | accuracy=0.9906 | val_accuracy=0.9647
# Epoch 60: loss=0.4538 | accuracy=0.9927 | val_accuracy=0.9756
# Epoch 61: loss=0.4577 | accuracy=0.9896 | val_accuracy=0.9749
# Epoch 62: loss=0.4541 | accuracy=0.9930 | val_accuracy=0.9735
# Epoch 63: loss=0.4543 | accuracy=0.9923 | val_accuracy=0.9830
# Epoch 64: loss=0.4560 | accuracy=0.9927 | val_accuracy=0.9681
# Epoch 65: loss=0.4584 | accuracy=0.9913 | val_accuracy=0.9749
# Epoch 66: loss=0.4534 | accuracy=0.9927 | val_accuracy=0.9681
# Epoch 67: loss=0.4531 | accuracy=0.9927 | val_accuracy=0.9661
# Epoch 68: loss=0.4565 | accuracy=0.9908 | val_accuracy=0.9674
# Epoch 69: loss=0.4555 | accuracy=0.9915 | val_accuracy=0.9735
# Epoch 70: loss=0.4576 | accuracy=0.9898 | val_accuracy=0.9728
# Epoch 71: loss=0.4547 | accuracy=0.9920 | val_accuracy=0.9749
# Epoch 72: loss=0.4504 | accuracy=0.9939 | val_accuracy=0.9728
# Epoch 73: loss=0.4546 | accuracy=0.9922 | val_accuracy=0.9742
# Epoch 74: loss=0.4521 | accuracy=0.9920 | val_accuracy=0.9661
# Epoch 75: loss=0.4528 | accuracy=0.9927 | val_accuracy=0.9708
# Epoch 76: loss=0.4561 | accuracy=0.9917 | val_accuracy=0.9756
# Epoch 77: loss=0.4510 | accuracy=0.9920 | val_accuracy=0.9762
# Epoch 78: loss=0.4486 | accuracy=0.9959 | val_accuracy=0.9722
# Epoch 79: loss=0.4500 | accuracy=0.9937 | val_accuracy=0.9864
# Epoch 80: loss=0.4495 | accuracy=0.9952 | val_accuracy=0.9701
# Epoch 81: loss=0.4496 | accuracy=0.9946 | val_accuracy=0.9742
# Epoch 82: loss=0.4489 | accuracy=0.9947 | val_accuracy=0.9722
# Epoch 83: loss=0.4483 | accuracy=0.9942 | val_accuracy=0.9735
# Epoch 84: loss=0.4496 | accuracy=0.9940 | val_accuracy=0.9769
# Epoch 85: loss=0.4535 | accuracy=0.9923 | val_accuracy=0.9627
# Epoch 86: loss=0.4517 | accuracy=0.9932 | val_accuracy=0.9484
# Epoch 87: loss=0.4488 | accuracy=0.9942 | val_accuracy=0.9823
# Epoch 88: loss=0.4468 | accuracy=0.9954 | val_accuracy=0.9769
# Epoch 89: loss=0.4468 | accuracy=0.9963 | val_accuracy=0.9769
# Epoch 90: loss=0.4557 | accuracy=0.9920 | val_accuracy=0.9525
# Epoch 91: loss=0.4530 | accuracy=0.9925 | val_accuracy=0.9776
# Epoch 92: loss=0.4461 | accuracy=0.9963 | val_accuracy=0.9803
# Epoch 93: loss=0.4476 | accuracy=0.9954 | val_accuracy=0.9776
# Epoch 94: loss=0.4484 | accuracy=0.9946 | val_accuracy=0.9769
# Epoch 95: loss=0.4459 | accuracy=0.9963 | val_accuracy=0.9837
# Epoch 96: loss=0.4435 | accuracy=0.9969 | val_accuracy=0.9817
# Epoch 97: loss=0.4470 | accuracy=0.9961 | val_accuracy=0.9810
# Epoch 98: loss=0.4468 | accuracy=0.9957 | val_accuracy=0.9769
# Epoch 99: loss=0.4455 | accuracy=0.9961 | val_accuracy=0.9830
# Epoch 100: loss=0.4458 | accuracy=0.9957 | val_accuracy=0.9830

# %%
y_pred, y_true = evaluate(model, test_loader)

acc = accuracy_score(y_true, y_pred)
prec = precision_score(y_true, y_pred, average="macro")
rec = recall_score(y_true, y_pred, average="macro")
f1 = f1_score(y_true, y_pred, average="macro")

print(f"accuracy = {acc}\nprecision = {prec}\nrecall = {rec}\nf1-score = {f1}")
# Out:
# accuracy = 0.9579233118425518
# precision = 0.9579138290495841
# recall = 0.9581972693351449
# f1-score = 0.9579158903129108

# %%
model_profile = get_profile(model)
latency = benchmark(model, test_loader)

data = {
    "Model": ["CNN1D"],
    "Params (K)": int(model_profile[1]),
    "FLOPs (M)": model_profile[0],
    "Latency (ms)": latency,
}

df = pd.DataFrame(data)
df
# Out:
# [INFO] Register count_convNd() for <class 'torch.nn.modules.conv.Conv1d'>.
# [INFO] Register count_normalization() for <class 'torch.nn.modules.batchnorm.BatchNorm1d'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.activation.ReLU'>.
# [INFO] Register count_adap_avgpool() for <class 'torch.nn.modules.pooling.AdaptiveAvgPool1d'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.pooling.AdaptiveMaxPool1d'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.container.Sequential'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.pooling.MaxPool1d'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.dropout.Dropout'>.
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
#    Model  Params (K)  FLOPs (M)  Latency (ms)
# 0  CNN1D       55460  3104448.0      0.099443

# %%
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8,6))

sns.heatmap(cm,
            annot=True,
            fmt='d',
            cmap='Blues')

plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix (UCI-HAR)")
plt.show()

# %%
features, labels = extract_features(model, test_loader)

tsne = TSNE(
    n_components=2,
    perplexity=30,
    random_state=42
)

embedding = tsne.fit_transform(features)


activity_names = [
    "Walking",
    "Walking Upstairs",
    "Walking Downstairs",
    "Sitting",
    "Standing",
    "Laying"
]

plt.figure(figsize=(10,8))

for i in range(6):
    idx = labels == i

    plt.scatter(
        embedding[idx,0],
        embedding[idx,1],
        label=activity_names[i],
        alpha=0.6,
        s=10
    )

plt.legend()
plt.title("t-SNE of CNN Features")
plt.show()
