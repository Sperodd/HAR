# %%
# !unzip -q "/content/drive/MyDrive/deep/archive.zip" -d "/content/dataset/"

# %%
# !pip install thop
# Out:
# Collecting thop
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from thop) (2.11.0+cu128)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->thop) (3.29.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (4.15.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (2025.3.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->thop) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->thop) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->thop) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->thop) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->thop) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->thop) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->thop) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->thop) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->thop) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->thop) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->thop) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->thop) (12.8.90)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch->thop) (1.5.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->thop) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->thop) (3.0.3)
# Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Installing collected packages: thop
# Successfully installed thop-0.1.1.post2209072238

# %%
import numpy as np
import torch

# %%
INPUT_SIGNAL_TYPES = [
    "body_acc_x_",
    "body_acc_y_",
    "body_acc_z_",
    "body_gyro_x_",
    "body_gyro_y_",
    "body_gyro_z_",
    "total_acc_x_",
    "total_acc_y_",
    "total_acc_z_"
]

LABELS = [
    "WALKING",
    "WALKING_UPSTAIRS",
    "WALKING_DOWNSTAIRS",
    "SITTING",
    "STANDING",
    "LAYING"
]

# %%
TRAIN = "train/"
TEST = "test/"

DATASET_PATH = "/content/dataset/UCI-HAR Dataset/"

def load_X(X_signals_paths):
    X_signals = []

    for signal_type_path in X_signals_paths:
        series_list = []

        with open(signal_type_path, 'r') as file:
            for row in file:
                row_clean = row.replace('  ', ' ')
                row_clean = row_clean.strip()
                serie = row_clean.split(' ')
                serie_array = np.array(serie, dtype=np.float32)
                series_list.append(serie_array)

        X_signals.append(series_list)

    X_signals = np.array(X_signals)
    return np.transpose(X_signals, (1, 2, 0))

def load_y(y_path):
    with open(y_path, 'r') as file:
        labels = [int(line.strip()) for line in file]
    return np.array(labels, dtype=np.int32) - 1

# %%
X_train_signals_paths = [
    DATASET_PATH + TRAIN + "Inertial Signals/" + signal + "train.txt" for signal in INPUT_SIGNAL_TYPES
]
X_test_signals_paths = [
    DATASET_PATH + TEST + "Inertial Signals/" + signal + "test.txt" for signal in INPUT_SIGNAL_TYPES
]

y_train_path = DATASET_PATH + TRAIN + "y_train.txt"
y_test_path = DATASET_PATH + TEST + "y_test.txt"


X_train = load_X(X_train_signals_paths)
X_test = load_X(X_test_signals_paths)
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)

y_train = load_y(y_train_path)
y_test = load_y(y_test_path)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (7352, 128, 9)
# X_test shape: (2947, 128, 9)
# y_train shape: (7352,)
# y_test shape: (2947,)

# %%
# GPU 사용 가능 여부 확인 for pytorch
device_available = torch.cuda.is_available()
print(f"GPU 사용 가능 여부: {device_available}")

if device_available:
    device_name = torch.cuda.get_device_name(0)
    print(f"사용 중인 GPU 장치: {device_name}")

    device = torch.device("cuda")
    x = torch.tensor([1.0, 2.0]).to(device)
    print(f"텐서가 할당된 장치: {x.device}")
else:
    print("GPU를 인식하지 못했습니다. 설정을 다시 확인해주세요.")
    model = "cpu"
# Out:
# GPU 사용 가능 여부: True
# 사용 중인 GPU 장치: Tesla T4
# 텐서가 할당된 장치: cuda:0

# %%
import time
import pandas as pd
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from thop import profile
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.manifold import TSNE

# %%
class HAR_Dataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.float32).permute(0, 2, 1)  # (B, 9, 128)
        self.y = torch.tensor(y, dtype=torch.long)

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# %%
train_dataset = HAR_Dataset(X_train, y_train)
test_dataset  = HAR_Dataset(X_test, y_test)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader  = DataLoader(test_dataset, batch_size=64, shuffle=False)

# %%
X_raw = X_test.reshape(X_test.shape[0], -1)

print(f"X_raw shape = {X_raw.shape}")

tsne = TSNE(
    n_components=2,
    perplexity=30,
    random_state=42
)

embedding = tsne.fit_transform(X_raw)

activity_names = [
    "Walking",
    "Walking Upstairs",
    "Walking Downstairs",
    "Sitting",
    "Standing",
    "Laying"
]

plt.figure(figsize=(10,8))

for i in range(6):
    idx = y_test == i

    plt.scatter(
        embedding[idx,0],
        embedding[idx,1],
        s=10,
        alpha=0.6,
        label=activity_names[i]
    )

plt.legend()
plt.title("Raw UCI-HAR t-SNE")
plt.show()
# Out:
# X_raw shape = (2947, 1152)

# %% [markdown]
# # **GoogLeNet의 Inception을 구현해보자**
# InceptionBlock을 따로 객체로 구현하면 될듯 \
# x를 받아 각각 \
# 1x1, 3x3, 5x 5, maxpooling 3x3 \
# 을 통과시킨 뒤 concat

# %%
class InceptionBlock(nn.Module):
  def __init__(self, in_channels, out_channels):
    super().__init__()

    mid_channels = out_channels // 4

    self.branch1 = nn.Sequential(
      nn.Conv1d(in_channels, mid_channels, kernel_size=1),
      nn.BatchNorm1d(mid_channels),
      nn.ReLU()
    )

    self.branch2 = nn.Sequential(
      nn.Conv1d(in_channels, mid_channels, kernel_size=3, padding=1),
      nn.BatchNorm1d(mid_channels),
      nn.ReLU()
    )

    self.branch3 = nn.Sequential(
      nn.Conv1d(in_channels, mid_channels, kernel_size=5, padding=2),
      nn.BatchNorm1d(mid_channels),
      nn.ReLU()
    )

    self.branch4 = nn.Sequential(
      nn.MaxPool1d(kernel_size=3, stride=1, padding=1),
      nn.Conv1d(in_channels, mid_channels, kernel_size=1),
      nn.BatchNorm1d(mid_channels),
      nn.ReLU()
    )

    total_mid_channels = mid_channels * 4
    self.proj = nn.Sequential(
      nn.Conv1d(total_mid_channels, out_channels, kernel_size=1),
      nn.BatchNorm1d(out_channels)
    )


  def forward(self, x):
    f1 = self.branch1(x)
    f2 = self.branch2(x)
    f3 = self.branch3(x)
    f4 = self.branch4(x)

    out = torch.cat([f1, f2, f3, f4], dim=1)
    out = self.proj(out)
    return F.relu(out)

# %%
class MyModel(nn.Module):
    def __init__(self):
        super().__init__()

        self.prep = nn.Sequential(
            nn.Conv1d(9, 64, kernel_size=3, padding=1),
            nn.BatchNorm1d(64),
            nn.ReLU()
        )

        self.inception1 = InceptionBlock(64, 64)
        self.pool1 = nn.MaxPool1d(kernel_size=2)

        self.inception2 = InceptionBlock(64, 128)
        self.pool2 = nn.MaxPool1d(kernel_size=2)

        self.inception3 = InceptionBlock(128, 128)

        self.dropout = nn.Dropout(0.4)
        self.fc = nn.LazyLinear(6)

    def forward(self, x, return_feature=False):

        x = self.prep(x)

        x = self.inception1(x)
        x = self.pool1(x)
        x = self.inception2(x)
        x = self.pool2(x)
        x = self.inception3(x)

        x = F.adaptive_avg_pool1d(x, 1)
        feat = torch.flatten(x, 1)
        x = self.dropout(feat)
        logits = self.fc(x)

        if return_feature:
            return logits, feat

        return logits

# %%
def train(model, loader):
    model.train()

    total_loss = 0
    correct = 0
    total = 0

    for X, y in loader:
        X = X.to(device)
        y = y.to(device)
        optimizer.zero_grad()

        outputs = model(X)
        loss = criterion(outputs, y)

        loss.backward()
        optimizer.step()

        total_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total += y.size(0)
        correct += (predicted == y).sum().item()

    epoch_loss = total_loss / len(loader)
    epoch_acc = correct / total
    return epoch_loss, epoch_acc

def evaluate(model, loader):
    model.eval()

    all_preds = []
    all_labels = []

    with torch.no_grad():
        for X, y in loader:
            X = X.to(device)
            y = y.to(device)
            outputs = model(X)
            preds = torch.argmax(outputs, dim=1)

            all_preds.append(preds)
            all_labels.append(y)

    return (torch.cat(all_preds).cpu(), torch.cat(all_labels).cpu())

def count_params(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def get_profile(model):
  dummy_input = torch.randn(1, 9, 128).to(device)
  flops, params = profile(model, inputs=(dummy_input,))
  return flops, params

def benchmark(model, loader):
  model.eval()
  torch.cuda.synchronize()

  start = time.time()
  with torch.no_grad():
    for x, _ in loader:
      x = x.to(device)
      _ = model(x)

  torch.cuda.synchronize()
  end = time.time()

  return end - start

def extract_features(model, loader):
    model.eval()

    features = []
    labels = []

    with torch.no_grad():
        for X, y in loader:
            X = X.to(device)

            _, feat = model(X, return_feature=True)

            features.append(feat.cpu().numpy())
            labels.append(y.numpy())

    features = np.concatenate(features)
    labels = np.concatenate(labels)

    return features, labels

# %%
model = MyModel().to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

for epoch in range(100):
    loss, acc = train(model, train_loader)

    print(f"Epoch {epoch+1}: loss={loss:.4f} | accuracy={acc:.4f}")
# Out:
# Epoch 1: loss=0.3316 | accuracy=0.9066
# Epoch 2: loss=0.1598 | accuracy=0.9404
# Epoch 3: loss=0.1254 | accuracy=0.9508
# Epoch 4: loss=0.1205 | accuracy=0.9514
# Epoch 5: loss=0.1151 | accuracy=0.9529
# Epoch 6: loss=0.1069 | accuracy=0.9535
# Epoch 7: loss=0.1012 | accuracy=0.9562
# Epoch 8: loss=0.1065 | accuracy=0.9535
# Epoch 9: loss=0.1060 | accuracy=0.9588
# Epoch 10: loss=0.0996 | accuracy=0.9574
# Epoch 11: loss=0.0963 | accuracy=0.9600
# Epoch 12: loss=0.0893 | accuracy=0.9606
# Epoch 13: loss=0.0867 | accuracy=0.9619
# Epoch 14: loss=0.0912 | accuracy=0.9611
# Epoch 15: loss=0.0894 | accuracy=0.9634
# Epoch 16: loss=0.0803 | accuracy=0.9660
# Epoch 17: loss=0.0804 | accuracy=0.9684
# Epoch 18: loss=0.0715 | accuracy=0.9716
# Epoch 19: loss=0.0816 | accuracy=0.9665
# Epoch 20: loss=0.0712 | accuracy=0.9712
# Epoch 21: loss=0.0724 | accuracy=0.9721
# Epoch 22: loss=0.0720 | accuracy=0.9686
# Epoch 23: loss=0.0730 | accuracy=0.9689
# Epoch 24: loss=0.0713 | accuracy=0.9728
# Epoch 25: loss=0.0603 | accuracy=0.9752
# Epoch 26: loss=0.0598 | accuracy=0.9751
# Epoch 27: loss=0.0603 | accuracy=0.9762
# Epoch 28: loss=0.0632 | accuracy=0.9761
# Epoch 29: loss=0.0525 | accuracy=0.9799
# Epoch 30: loss=0.0520 | accuracy=0.9801
# Epoch 31: loss=0.0592 | accuracy=0.9771
# Epoch 32: loss=0.0548 | accuracy=0.9795
# Epoch 33: loss=0.0443 | accuracy=0.9835
# Epoch 34: loss=0.0489 | accuracy=0.9812
# Epoch 35: loss=0.0444 | accuracy=0.9823
# Epoch 36: loss=0.0393 | accuracy=0.9850
# Epoch 37: loss=0.0373 | accuracy=0.9861
# Epoch 38: loss=0.0329 | accuracy=0.9875
# Epoch 39: loss=0.0334 | accuracy=0.9880
# Epoch 40: loss=0.0362 | accuracy=0.9875
# Epoch 41: loss=0.0325 | accuracy=0.9898
# Epoch 42: loss=0.0392 | accuracy=0.9852
# Epoch 43: loss=0.0350 | accuracy=0.9876
# Epoch 44: loss=0.0294 | accuracy=0.9890
# Epoch 45: loss=0.0378 | accuracy=0.9872
# Epoch 46: loss=0.0265 | accuracy=0.9899
# Epoch 47: loss=0.0274 | accuracy=0.9893
# Epoch 48: loss=0.0275 | accuracy=0.9893
# Epoch 49: loss=0.0276 | accuracy=0.9902
# Epoch 50: loss=0.0242 | accuracy=0.9909
# Epoch 51: loss=0.0327 | accuracy=0.9886
# Epoch 52: loss=0.0258 | accuracy=0.9901
# Epoch 53: loss=0.0266 | accuracy=0.9903
# Epoch 54: loss=0.0212 | accuracy=0.9922
# Epoch 55: loss=0.0271 | accuracy=0.9905
# Epoch 56: loss=0.0289 | accuracy=0.9890
# Epoch 57: loss=0.0171 | accuracy=0.9932
# Epoch 58: loss=0.0207 | accuracy=0.9937
# Epoch 59: loss=0.0175 | accuracy=0.9940
# Epoch 60: loss=0.0172 | accuracy=0.9936
# Epoch 61: loss=0.0170 | accuracy=0.9928
# Epoch 62: loss=0.0175 | accuracy=0.9937
# Epoch 63: loss=0.0178 | accuracy=0.9918
# Epoch 64: loss=0.0129 | accuracy=0.9952
# Epoch 65: loss=0.0181 | accuracy=0.9929
# Epoch 66: loss=0.0160 | accuracy=0.9946
# Epoch 67: loss=0.0187 | accuracy=0.9929
# Epoch 68: loss=0.0174 | accuracy=0.9931
# Epoch 69: loss=0.0171 | accuracy=0.9943
# Epoch 70: loss=0.0289 | accuracy=0.9914
# Epoch 71: loss=0.0335 | accuracy=0.9867
# Epoch 72: loss=0.0175 | accuracy=0.9944
# Epoch 73: loss=0.0182 | accuracy=0.9921
# Epoch 74: loss=0.0175 | accuracy=0.9929
# Epoch 75: loss=0.0177 | accuracy=0.9940
# Epoch 76: loss=0.0162 | accuracy=0.9937
# Epoch 77: loss=0.0112 | accuracy=0.9958
# Epoch 78: loss=0.0134 | accuracy=0.9952
# Epoch 79: loss=0.0148 | accuracy=0.9942
# Epoch 80: loss=0.0097 | accuracy=0.9969
# Epoch 81: loss=0.0126 | accuracy=0.9954
# Epoch 82: loss=0.0132 | accuracy=0.9946
# Epoch 83: loss=0.0116 | accuracy=0.9956
# Epoch 84: loss=0.0186 | accuracy=0.9942
# Epoch 85: loss=0.0175 | accuracy=0.9937
# Epoch 86: loss=0.0094 | accuracy=0.9963
# Epoch 87: loss=0.0092 | accuracy=0.9977
# Epoch 88: loss=0.0103 | accuracy=0.9967
# Epoch 89: loss=0.0076 | accuracy=0.9976
# Epoch 90: loss=0.0180 | accuracy=0.9936
# Epoch 91: loss=0.0139 | accuracy=0.9944
# Epoch 92: loss=0.0102 | accuracy=0.9965
# Epoch 93: loss=0.0233 | accuracy=0.9917
# Epoch 94: loss=0.0201 | accuracy=0.9924
# Epoch 95: loss=0.0117 | accuracy=0.9961
# Epoch 96: loss=0.0078 | accuracy=0.9969
# Epoch 97: loss=0.0135 | accuracy=0.9948
# Epoch 98: loss=0.0040 | accuracy=0.9990
# Epoch 99: loss=0.0139 | accuracy=0.9959
# Epoch 100: loss=0.0085 | accuracy=0.9970

# %%
y_pred, y_true = evaluate(model, test_loader)

acc = accuracy_score(y_true, y_pred)
prec = precision_score(y_true, y_pred, average="macro")
rec = recall_score(y_true, y_pred, average="macro")
f1 = f1_score(y_true, y_pred, average="macro")

print(f"accuracy = {acc}\nprecision = {prec}\nrecall = {rec}\nf1-score = {f1}")
# Out:
# accuracy = 0.9626739056667798
# precision = 0.9628598348755398
# recall = 0.9630418931642298
# f1-score = 0.9623816991768016

# %%
model_profile = get_profile(model)
latency = benchmark(model, test_loader)

data = {
    "Model": ["CNN1D"],
    "Params (K)": int(model_profile[1]),
    "FLOPs (M)": model_profile[0],
    "Latency (ms)": latency,
}

df = pd.DataFrame(data)
df
# Out:
# [INFO] Register count_convNd() for <class 'torch.nn.modules.conv.Conv1d'>.
# [INFO] Register count_normalization() for <class 'torch.nn.modules.batchnorm.BatchNorm1d'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.activation.ReLU'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.container.Sequential'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.pooling.MaxPool1d'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.dropout.Dropout'>.
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
#    Model  Params (K)  FLOPs (M)  Latency (ms)
# 0  CNN1D      113158  6447872.0      0.179504

# %%
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8,6))

sns.heatmap(cm,
            annot=True,
            fmt='d',
            cmap='Blues')

plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix (UCI-HAR)")
plt.show()

# %%
features, labels = extract_features(model, test_loader)

tsne = TSNE(
    n_components=2,
    perplexity=30,
    random_state=42
)

embedding = tsne.fit_transform(features)


activity_names = [
    "Walking",
    "Walking Upstairs",
    "Walking Downstairs",
    "Sitting",
    "Standing",
    "Laying"
]

plt.figure(figsize=(10,8))

for i in range(6):
    idx = labels == i

    plt.scatter(
        embedding[idx,0],
        embedding[idx,1],
        label=activity_names[i],
        alpha=0.6,
        s=10
    )

plt.legend()
plt.title("t-SNE of CNN Features")
plt.show()
