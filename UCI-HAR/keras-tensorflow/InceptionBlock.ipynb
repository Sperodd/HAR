# %% [markdown]
# ## **UCI-HAR 가져오는 코드**
# 대충 모델 앞에 붙여서 쓰셈 ㅇㅇ\
# 드라이브에 올린 zip파일을 직접 해제하여 메모리에 올려서 사용

# %%
# !unzip -q "/content/drive/MyDrive/deep/archive.zip" -d "/content/dataset/"

# %%
import numpy as np

# %%
INPUT_SIGNAL_TYPES = [
    "body_acc_x_",
    "body_acc_y_",
    "body_acc_z_",
    "body_gyro_x_",
    "body_gyro_y_",
    "body_gyro_z_",
    "total_acc_x_",
    "total_acc_y_",
    "total_acc_z_"
]

LABELS = [
    "WALKING",
    "WALKING_UPSTAIRS",
    "WALKING_DOWNSTAIRS",
    "SITTING",
    "STANDING",
    "LAYING"
]

# %%
TRAIN = "train/"
TEST = "test/"

DATASET_PATH = "/content/dataset/UCI-HAR Dataset/"

def load_X(X_signals_paths):
    X_signals = []

    for signal_type_path in X_signals_paths:
        series_list = []

        with open(signal_type_path, 'r') as file:
            for row in file:
                row_clean = row.replace('  ', ' ')
                row_clean = row_clean.strip()
                serie = row_clean.split(' ')
                serie_array = np.array(serie, dtype=np.float32)
                series_list.append(serie_array)

        X_signals.append(series_list)

    X_signals = np.array(X_signals)
    return np.transpose(X_signals, (1, 2, 0))

def load_y(y_path):
    with open(y_path, 'r') as file:
        labels = [int(line.strip()) for line in file]
    return np.array(labels, dtype=np.int32) - 1

# %%
X_train_signals_paths = [
    DATASET_PATH + TRAIN + "Inertial Signals/" + signal + "train.txt" for signal in INPUT_SIGNAL_TYPES
]
X_test_signals_paths = [
    DATASET_PATH + TEST + "Inertial Signals/" + signal + "test.txt" for signal in INPUT_SIGNAL_TYPES
]

y_train_path = DATASET_PATH + TRAIN + "y_train.txt"
y_test_path = DATASET_PATH + TEST + "y_test.txt"


X_train = load_X(X_train_signals_paths)
X_test = load_X(X_test_signals_paths)
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)

y_train = load_y(y_train_path)
y_test = load_y(y_test_path)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (7352, 128, 9)
# X_test shape: (2947, 128, 9)
# y_train shape: (7352,)
# y_test shape: (2947,)

# %%
print(X_train[0])
print(y_train[0])
# Out:
# [[ 1.808515e-04  1.076681e-02  5.556068e-02 ...  1.012817e+00
#   -1.232167e-01  1.029341e-01]
#  [ 1.013856e-02  6.579480e-03  5.512483e-02 ...  1.022833e+00
#   -1.268756e-01  1.056872e-01]
#  [ 9.275574e-03  8.928878e-03  4.840473e-02 ...  1.022028e+00
#   -1.240037e-01  1.021025e-01]
#  ...
#  [-1.147484e-03  1.714439e-04  2.647864e-03 ...  1.018445e+00
#   -1.240696e-01  1.003852e-01]
#  [-2.222655e-04  1.574181e-03  2.381057e-03 ...  1.019372e+00
#   -1.227451e-01  9.987355e-02]
#  [ 1.575500e-03  3.070189e-03 -2.269757e-03 ...  1.021171e+00
#   -1.213260e-01  9.498741e-02]]
# 4

# %%
# # GPU 사용 가능 여부 확인 for pytorch
# device_available = torch.cuda.is_available()
# print(f"GPU 사용 가능 여부: {device_available}")

# if device_available:
#     device_name = torch.cuda.get_device_name(0)
#     print(f"사용 중인 GPU 장치: {device_name}")

#     device = torch.device("cuda")
#     x = torch.tensor([1.0, 2.0]).to(device)
#     print(f"텐서가 할당된 장치: {x.device}")
# else:
#     print("GPU를 인식하지 못했습니다. 설정을 다시 확인해주세요.")

# %% [markdown]
# # **모델**
# Inpcetion Block 3개 정도 쌓아서 성능 확인 \
# 각각 filter size = [1, 3, 5, 7] 정도.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.models import load_model

# %%
def Inception_block(x, filters):
  f1 = layers.Conv1D(filters, 1, padding='same', activation='relu')(x)
  f2 = layers.Conv1D(filters, 3, padding='same', activation='relu')(x)
  f3 = layers.Conv1D(filters, 5, padding='same', activation='relu')(x)
  f4 = layers.Conv1D(filters, 7, padding='same', activation='relu')(x)

  x = layers.Concatenate()([f1, f2, f3, f4])
  return x

# %%
# Functional API 방식으로 작성.
inputs = layers.Input(shape=(128, 9))

x = layers.Conv1D(64, 3, padding='same', activation='relu')(inputs)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)

x = Inception_block(x, 32)
x = Inception_block(x, 32)
x = Inception_block(x, 32)

x = layers.GlobalAveragePooling1D()(x)
x = layers.Dropout(0.3)(x)

x = layers.Dense(128, activation='relu')(x)
outputs = layers.Dense(6, activation='softmax')(x)

model = models.Model(inputs, outputs)

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 9)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 128, 64)   │      1,792 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 128, 64)   │        256 │ conv1d[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 128, 64)   │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, 128, 32)   │      2,080 │ activation[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_2 (Conv1D)   │ (None, 128, 32)   │      6,176 │ activation[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_3 (Conv1D)   │ (None, 128, 32)   │     10,272 │ activation[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_4 (Conv1D)   │ (None, 128, 32)   │     14,368 │ activation[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 128, 128)  │          0 │ conv1d_1[0][0],   │
# │ (Concatenate)       │                   │            │ conv1d_2[0][0],   │
# │                     │                   │            │ conv1d_3[0][0],   │
# │                     │                   │            │ conv1d_4[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_5 (Conv1D)   │ (None, 128, 32)   │      4,128 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_6 (Conv1D)   │ (None, 128, 32)   │     12,320 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_7 (Conv1D)   │ (None, 128, 32)   │     20,512 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_8 (Conv1D)   │ (None, 128, 32)   │     28,704 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 128, 128)  │          0 │ conv1d_5[0][0],   │
# │ (Concatenate)       │                   │            │ conv1d_6[0][0],   │
# │                     │                   │            │ conv1d_7[0][0],   │
# │                     │                   │            │ conv1d_8[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_9 (Conv1D)   │ (None, 128, 32)   │      4,128 │ concatenate_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_10 (Conv1D)  │ (None, 128, 32)   │     12,320 │ concatenate_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_11 (Conv1D)  │ (None, 128, 32)   │     20,512 │ concatenate_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_12 (Conv1D)  │ (None, 128, 32)   │     28,704 │ concatenate_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 128, 128)  │          0 │ conv1d_9[0][0],   │
# │ (Concatenate)       │                   │            │ conv1d_10[0][0],  │
# │                     │                   │            │ conv1d_11[0][0],  │
# │                     │                   │            │ conv1d_12[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ concatenate_2[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128)       │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128)       │     16,512 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 6)         │        774 │ dense[0][0]       │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 183,558 (717.02 KB)
#  Trainable params: 183,430 (716.52 KB)
#  Non-trainable params: 128 (512.00 B)

# %%
callbacks= [
    ModelCheckpoint(
        "best_model.keras",
        monitor="val_loss",
        save_best_only=True,
        mode='min',
        verbose=1
    )
]

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
history = model.fit(X_train, y_train, validation_split=0.2, epochs=50, callbacks=callbacks)
# Out:
# Epoch 1/50
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6553 - loss: 0.7981
# Epoch 1: val_loss improved from None to 0.47662, saving model to best_model.keras
#
# Epoch 1: finished saving model to best_model.keras
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 30s 67ms/step - accuracy: 0.8233 - loss: 0.4287 - val_accuracy: 0.8776 - val_loss: 0.4766
# Epoch 2/50
# 180/184 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9484 - loss: 0.1287
# Epoch 2: val_loss improved from 0.47662 to 0.29487, saving model to best_model.keras
#
# Epoch 2: finished saving model to best_model.keras
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9468 - loss: 0.1319 - val_accuracy: 0.9014 - val_loss: 0.2949
# Epoch 3/50
# 182/184 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9522 - loss: 0.1105
# Epoch 3: val_loss did not improve from 0.29487
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9544 - loss: 0.1079 - val_accuracy: 0.8892 - val_loss: 0.4205
# Epoch 4/50
# 178/184 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9517 - loss: 0.1269
# Epoch 4: val_loss did not improve from 0.29487
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9514 - loss: 0.1285 - val_accuracy: 0.8892 - val_loss: 0.7089
# Epoch 5/50
# 183/184 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9521 - loss: 0.0944
# Epoch 5: val_loss did not improve from 0.29487
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9565 - loss: 0.0920 - val_accuracy: 0.8906 - val_loss: 0.4459
# Epoch 6/50
# 183/184 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9592 - loss: 0.0885
# Epoch 6: val_loss did not improve from 0.29487
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9585 - loss: 0.0870 - val_accuracy: 0.9225 - val_loss: 0.4296
# Epoch 7/50
# 182/184 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9577 - loss: 0.0872
# Epoch 7: val_loss did not improve from 0.29487
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9580 - loss: 0.0907 - val_accuracy: 0.9205 - val_loss: 0.3447
# Epoch 8/50
# 178/184 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9532 - loss: 0.0980
# Epoch 8: val_loss did not improve from 0.29487
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9554 - loss: 0.0967 - val_accuracy: 0.9137 - val_loss: 0.4357
# Epoch 9/50
# 182/184 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9586 - loss: 0.0885
# Epoch 9: val_loss did not improve from 0.29487
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9606 - loss: 0.0858 - val_accuracy: 0.9211 - val_loss: 0.4311
# Epoch 10/50
# 180/184 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9622 - loss: 0.0831
# Epoch 10: val_loss did not improve from 0.29487
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9626 - loss: 0.0842 - val_accuracy: 0.8688 - val_loss: 0.3235
# Epoch 11/50
# 180/184 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9655 - loss: 0.0746
# Epoch 11: val_loss did not improve from 0.29487
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9655 - loss: 0.0776 - val_accuracy: 0.8987 - val_loss: 0.5291
# Epoch 12/50
# 178/184 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9683 - loss: 0.0808
# Epoch 12: val_loss did not improve from 0.29487
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9643 - loss: 0.0836 - val_accuracy: 0.9218 - val_loss: 0.4601
# Epoch 13/50
# 181/184 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9631 - loss: 0.0761
# Epoch 13: val_loss did not improve from 0.29487
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9634 - loss: 0.0768 - val_accuracy: 0.8899 - val_loss: 0.6736
# Epoch 14/50
# 181/184 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9590 - loss: 0.1019
# Epoch 14: val_loss did not improve from 0.29487
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9641 - loss: 0.0840 - val_accuracy: 0.9021 - val_loss: 0.6852
# Epoch 15/50
# 178/184 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9604 - loss: 0.0928
# Epoch 15: val_loss did not improve from 0.29487
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9597 - loss: 0.0942 - val_accuracy: 0.9177 - val_loss: 0.4939
# Epoch 16/50
# 181/184 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9695 - loss: 0.0677
# Epoch 16: val_loss did not improve from 0.29487
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9655 - loss: 0.0750 - val_accuracy: 0.9116 - val_loss: 0.3851
# Epoch 17/50
# 176/184 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9699 - loss: 0.0645
# Epoch 17: val_loss did not improve from 0.29487
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9670 - loss: 0.0703 - val_accuracy: 0.9137 - val_loss: 0.4338
# Epoch 18/50
# 181/184 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9665 - loss: 0.0746
# Epoch 18: val_loss did not improve from 0.29487
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9701 - loss: 0.0686 - val_accuracy: 0.9184 - val_loss: 0.4691
# Epoch 19/50
# 183/184 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9641 - loss: 0.0895
# Epoch 19: val_loss did not improve from 0.29487
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9645 - loss: 0.0850 - val_accuracy: 0.9327 - val_loss: 0.4652
# Epoch 20/50
# 178/184 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9687 - loss: 0.0719
# Epoch 20: val_loss improved from 0.29487 to 0.27018, saving model to best_model.keras
#
# Epoch 20: finished saving model to best_model.keras
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9672 - loss: 0.0754 - val_accuracy: 0.9096 - val_loss: 0.2702
# Epoch 21/50
# 177/184 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9690 - loss: 0.0671
# Epoch 21: val_loss did not improve from 0.27018
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9675 - loss: 0.0709 - val_accuracy: 0.9252 - val_loss: 0.4522
# Epoch 22/50
# 179/184 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9693 - loss: 0.0688
# Epoch 22: val_loss did not improve from 0.27018
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9680 - loss: 0.0757 - val_accuracy: 0.9225 - val_loss: 0.8070
# Epoch 23/50
# 179/184 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9668 - loss: 0.0813
# Epoch 23: val_loss did not improve from 0.27018
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9708 - loss: 0.0731 - val_accuracy: 0.9041 - val_loss: 0.6149
# Epoch 24/50
# 177/184 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9714 - loss: 0.0635
# Epoch 24: val_loss did not improve from 0.27018
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9696 - loss: 0.0732 - val_accuracy: 0.8919 - val_loss: 0.5446
# Epoch 25/50
# 180/184 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9737 - loss: 0.0550
# Epoch 25: val_loss did not improve from 0.27018
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9731 - loss: 0.0580 - val_accuracy: 0.9239 - val_loss: 0.5858
# Epoch 26/50
# 178/184 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9751 - loss: 0.0574
# Epoch 26: val_loss did not improve from 0.27018
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9730 - loss: 0.0590 - val_accuracy: 0.8912 - val_loss: 0.8484
# Epoch 27/50
# 181/184 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9711 - loss: 0.0619
# Epoch 27: val_loss did not improve from 0.27018
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9706 - loss: 0.0610 - val_accuracy: 0.9062 - val_loss: 0.6304
# Epoch 28/50
# 180/184 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9765 - loss: 0.0572
# Epoch 28: val_loss did not improve from 0.27018
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9759 - loss: 0.0592 - val_accuracy: 0.9266 - val_loss: 0.5117
# Epoch 29/50
# 178/184 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9742 - loss: 0.0551
# Epoch 29: val_loss did not improve from 0.27018
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9730 - loss: 0.0565 - val_accuracy: 0.9041 - val_loss: 0.8702
# Epoch 30/50
# 180/184 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9708 - loss: 0.0772
# Epoch 30: val_loss did not improve from 0.27018
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9704 - loss: 0.0776 - val_accuracy: 0.8926 - val_loss: 0.9048
# Epoch 31/50
# 181/184 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9690 - loss: 0.0663
# Epoch 31: val_loss did not improve from 0.27018
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9740 - loss: 0.0568 - val_accuracy: 0.9062 - val_loss: 0.8865
# Epoch 32/50
# 176/184 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9752 - loss: 0.0551
# Epoch 32: val_loss did not improve from 0.27018
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9760 - loss: 0.0558 - val_accuracy: 0.9089 - val_loss: 0.9246
# Epoch 33/50
# 179/184 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9733 - loss: 0.0629
# Epoch 33: val_loss did not improve from 0.27018
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9730 - loss: 0.0688 - val_accuracy: 0.9143 - val_loss: 1.0172
# Epoch 34/50
# 179/184 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9780 - loss: 0.0553
# Epoch 34: val_loss did not improve from 0.27018
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9753 - loss: 0.0576 - val_accuracy: 0.9198 - val_loss: 1.1117
# Epoch 35/50
# 180/184 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9728 - loss: 0.0597
# Epoch 35: val_loss did not improve from 0.27018
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9755 - loss: 0.0573 - val_accuracy: 0.9245 - val_loss: 0.8487
# Epoch 36/50
# 181/184 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9719 - loss: 0.0813
# Epoch 36: val_loss did not improve from 0.27018
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9752 - loss: 0.0665 - val_accuracy: 0.9150 - val_loss: 0.6743
# Epoch 37/50
# 179/184 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9736 - loss: 0.0627
# Epoch 37: val_loss did not improve from 0.27018
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9757 - loss: 0.0568 - val_accuracy: 0.9069 - val_loss: 1.9703
# Epoch 38/50
# 179/184 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9766 - loss: 0.0531
# Epoch 38: val_loss did not improve from 0.27018
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9740 - loss: 0.0579 - val_accuracy: 0.9041 - val_loss: 1.8372
# Epoch 39/50
# 179/184 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9793 - loss: 0.0484
# Epoch 39: val_loss did not improve from 0.27018
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9755 - loss: 0.0565 - val_accuracy: 0.8892 - val_loss: 1.1260
# Epoch 40/50
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9724 - loss: 0.0643
# Epoch 40: val_loss did not improve from 0.27018
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9736 - loss: 0.0599 - val_accuracy: 0.9069 - val_loss: 1.4878
# Epoch 41/50
# 179/184 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9765 - loss: 0.0586
# Epoch 41: val_loss did not improve from 0.27018
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9738 - loss: 0.0818 - val_accuracy: 0.8654 - val_loss: 1.1201
# Epoch 42/50
# 178/184 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9736 - loss: 0.0596
# Epoch 42: val_loss did not improve from 0.27018
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9738 - loss: 0.0623 - val_accuracy: 0.9123 - val_loss: 1.1539
# Epoch 43/50
# 179/184 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9772 - loss: 0.0605
# Epoch 43: val_loss did not improve from 0.27018
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9753 - loss: 0.0628 - val_accuracy: 0.9116 - val_loss: 2.2268
# Epoch 44/50
# 179/184 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9730 - loss: 0.0619
# Epoch 44: val_loss did not improve from 0.27018
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9753 - loss: 0.0588 - val_accuracy: 0.9143 - val_loss: 1.4852
# Epoch 45/50
# 180/184 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9774 - loss: 0.0553
# Epoch 45: val_loss did not improve from 0.27018
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9767 - loss: 0.0543 - val_accuracy: 0.9171 - val_loss: 1.5366
# Epoch 46/50
# 179/184 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9770 - loss: 0.0567
# Epoch 46: val_loss did not improve from 0.27018
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9759 - loss: 0.0553 - val_accuracy: 0.8906 - val_loss: 1.7143
# Epoch 47/50
# 178/184 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9814 - loss: 0.0439
# Epoch 47: val_loss did not improve from 0.27018
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9804 - loss: 0.0455 - val_accuracy: 0.9205 - val_loss: 2.0150
# Epoch 48/50
# 180/184 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9762 - loss: 0.0546
# Epoch 48: val_loss did not improve from 0.27018
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9767 - loss: 0.0558 - val_accuracy: 0.8994 - val_loss: 1.7703
# Epoch 49/50
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9778 - loss: 0.0583
# Epoch 49: val_loss did not improve from 0.27018
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9776 - loss: 0.0553 - val_accuracy: 0.9191 - val_loss: 1.9188
# Epoch 50/50
# 182/184 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9768 - loss: 0.0487
# Epoch 50: val_loss did not improve from 0.27018
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9779 - loss: 0.0486 - val_accuracy: 0.9143 - val_loss: 1.7827

# %%
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='val loss')

plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training / Validation Loss')
plt.legend()
plt.show()

plt.plot(history.history['accuracy'], label='train accuracy')
plt.plot(history.history['val_accuracy'], label='val accuracy')

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training / Validation Accuracy')
plt.legend()

plt.show()

# %%
best_model = load_model("best_model.keras")
y_pred = best_model.predict(X_test)
loss, accuracy = best_model.evaluate(X_test, y_test)
# Out:
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9247 - loss: 0.3135

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

cm = confusion_matrix(y_test, np.argmax(y_pred, axis=1))
print(cm)

plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')

plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
# [[470   1  25   0   0   0]
#  [  3 444  24   0   0   0]
#  [  0   2 418   0   0   0]
#  [  0   5   0 411  74   1]
#  [  0   0   0  87 445   0]
#  [  0   0   0   0   0 537]]
